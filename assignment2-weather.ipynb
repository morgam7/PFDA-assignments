# %%
#import pandas
import pandas as pd

#Read in files with pandas
df = pd.read_csv('weatherreadings1.csv', index_col=0) #the first row is not data
df
# Out:
#                                             reportStartDateTime  \
# siteId
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ...                                                         ...
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#                                               reportEndDateTime  \
# siteId
# f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# ...
